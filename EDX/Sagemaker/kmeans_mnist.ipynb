# %% [markdown]
# # End-to-End Example #1
#
# 1. [Introduction](#Introduction)
# 2. [Prerequisites and Preprocessing](#Prequisites-and-Preprocessing)
#   1. [Permissions and environment variables](#Permissions-and-environment-variables)
#   2. [Data ingestion](#Data-ingestion)
#   3. [Data inspection](#Data-inspection)
#   4. [Data conversion](#Data-conversion)
# 3. [Training the K-Means model](#Training-the-K-Means-model)
# 4. [Set up hosting for the model](#Set-up-hosting-for-the-model)
# 5. [Validate the model for use](#Validate-the-model-for-use)

# %% [markdown]
# ## Introduction
#
# Welcome to our first end-to-end example! Today, we're working through a classification problem, specifically of images of handwritten digits, from zero to nine. Let's imagine that this dataset doesn't have labels, so we don't know for sure what the true answer is. In later examples, we'll show the value of "ground truth", as it's commonly known.
#
# Today, however, we need to get these digits classified without ground truth. A common method for doing this is a set of methods known as "clustering", and in particular, the method that we'll look at today is called k-means clustering. In this method, each point belongs to the cluster with the closest mean, and the data is partitioned into a number of clusters that is specified when framing the problem. In this case, since we know there are 10 clusters, and we have no labeled data (in the way we framed the problem), this is a good fit.
#
# To get started, we need to set up the environment with a few prerequisite steps, for permissions, configurations, and so on.

# %% [markdown]
# ## Prequisites and Preprocessing
#
# This notebook was tested in Amazon SageMaker Studio on a ml.t3.medium instance with Python 3 (Data Science) kernel.
#
# ### Permissions and environment variables
#
# Here we set up the linkage and authentication to AWS services. There are two parts to this:
#
# 1. The role(s) used to give learning and hosting access to your data. Here we extract the role you created earlier for accessing your notebook. See the documentation if you want to specify a different role.
# 1. The S3 bucket name that you want to use for training and model data. Here we use a default in the form of `sagemaker-{region}-{AWS account ID}`, but you may specify a different one if you wish.

# %%
# %matplotlib inline

# %%
from sagemaker import get_execution_role
from sagemaker.session import Session

role = get_execution_role()
bucket = Session().default_bucket()

# %% [markdown]
# ### Data ingestion
#
# Next, we read the dataset from the existing repository into memory, for preprocessing prior to training.  In this case we'll use the MNIST dataset [1], which contains 70K 28 x 28 pixel images of handwritten digits.  For more details, please see [here](http://yann.lecun.com/exdb/mnist/).
#
# This processing could be done *in situ* by Amazon Athena, Apache Spark in Amazon EMR, Amazon Redshift, etc., assuming the dataset is present in the appropriate location. Then, the next step would be to transfer the data to S3 for use in training. For small datasets, such as this one, reading into memory isn't onerous, though it would be for larger datasets.
#
# > [1] Y. LeCun, L. Bottou, Y. Bengio, and P. Haffner. Gradient-based learning applied to document recognition. Proceedings of the IEEE, 86(11):2278-2324, November 1998.

# %%
import pickle, gzip, numpy, boto3, json

# Load the dataset
s3 = boto3.client("s3")
s3.download_file(f"sagemaker-sample-files", "datasets/image/MNIST/mnist.pkl.gz", "mnist.pkl.gz")
with gzip.open("mnist.pkl.gz", "rb") as f:
    train_set, valid_set, test_set = pickle.load(f, encoding="latin1")

# %% [markdown]
# ### Data inspection
#
# Once the dataset is imported, it's typical as part of the machine learning process to inspect the data, understand the distributions, and determine what type(s) of preprocessing might be needed. You can perform those tasks right here in the notebook. As an example, let's go ahead and look at one of the digits that is part of the dataset.

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (2, 10)


def show_digit(img, caption="", subplot=None):
    if subplot is None:
        _, (subplot) = plt.subplots(1, 1)
    imgr = img.reshape((28, 28))
    subplot.axis("off")
    subplot.imshow(imgr, cmap="gray")
    plt.title(caption)


show_digit(train_set[0][30], f"This is a {train_set[1][30]}")

# %% [markdown]
# ## Training the K-Means model
#
# Once we have the data preprocessed and available in the correct format for training, the next step is to actually train the model using the data. Since this data is relatively small, it isn't meant to show off the performance of the k-means training algorithm.  But Amazon SageMaker's k-means has been tested on, and scales well with, multi-terabyte datasets.
#
# After setting training parameters, we kick off training, and poll for status until training is completed, which in this example, takes around 4 minutes.

# %%
from sagemaker import KMeans

data_location = f"s3://{bucket}/kmeans_highlevel_example/data"
output_location = f"s3://{bucket}/kmeans_example/output"

print(f"training data will be uploaded to: {data_location}")
print(f"training artifacts will be uploaded to: {output_location}")

kmeans = KMeans(
    role=role,
    instance_count=2,
    instance_type="ml.c4.xlarge",
    output_path=output_location,
    k=10,
    data_location=data_location,
)
# Out:
# training data will be uploaded to: s3://sagemaker-us-west-2-334644584919/kmeans_highlevel_example/data
# training artifacts will be uploaded to: s3://sagemaker-us-west-2-334644584919/kmeans_example/output

# %%
# %%time

kmeans.fit(kmeans.record_set(train_set[0]))
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-09-16 06:33:05 Starting - Starting the training job...
# 2021-09-16 06:33:28 Starting - Launching requested ML instancesProfilerReport-1631773984: InProgress
# ......
# 2021-09-16 06:34:28 Starting - Preparing the instances for training............
# 2021-09-16 06:36:28 Downloading - Downloading input data...
# 2021-09-16 06:37:07 Training - Training image download completed. Training in progress.
# 2021-09-16 06:37:07 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [09/16/2021 06:36:59 INFO 140274876057408] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'true', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': ''}
# [09/16/2021 06:36:59 INFO 140274876057408] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '784', 'k': '10', 'force_dense': 'True'}
# [09/16/2021 06:36:59 INFO 140274876057408] Final configuration: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '784', 'k': '10'}
# [09/16/2021 06:36:59 WARNING 140274876057408] Loggers have already been setup.
# [09/16/2021 06:36:59 INFO 140274876057408] Launching parameter server for role scheduler
# [09/16/2021 06:36:59 INFO 140274876057408] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-203-48.us-west-2.compute.internal', 'TRAINING_JOB_NAME': 'kmeans-2021-09-16-06-33-04-902', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-west-2:334644584919:training-job/kmeans-2021-09-16-06-33-04-902', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/64e5ba9e-6f6b-4a15-a53f-2b85f7e33e33', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'AWS_REGION': 'us-west-2', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/ff2b1344-d098-4cec-b672-78d0d20989ab', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/ff2b1344-d098-4cec-b672-78d0d20989ab', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml'}
# [09/16/2021 06:36:59 INFO 140274876057408] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-203-48.us-west-2.compute.internal', 'TRAINING_JOB_NAME': 'kmeans-2021-09-16-06-33-04-902', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-west-2:334644584919:training-job/kmeans-2021-09-16-06-33-04-902', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/64e5ba9e-6f6b-4a15-a53f-2b85f7e33e33', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'AWS_REGION': 'us-west-2', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/ff2b1344-d098-4cec-b672-78d0d20989ab', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/ff2b1344-d098-4cec-b672-78d0d20989ab', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '10.0.203.48', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '2'}
# [09/16/2021 06:36:59 INFO 140274876057408] Launching parameter server for role server
# [09/16/2021 06:36:59 INFO 140274876057408] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-203-48.us-west-2.compute.internal', 'TRAINING_JOB_NAME': 'kmeans-2021-09-16-06-33-04-902', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-west-2:334644584919:training-job/kmeans-2021-09-16-06-33-04-902', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/64e5ba9e-6f6b-4a15-a53f-2b85f7e33e33', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'AWS_REGION': 'us-west-2', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/ff2b1344-d098-4cec-b672-78d0d20989ab', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/ff2b1344-d098-4cec-b672-78d0d20989ab', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml'}
# [09/16/2021 06:36:59 INFO 140274876057408] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-203-48.us-west-2.compute.internal', 'TRAINING_JOB_NAME': 'kmeans-2021-09-16-06-33-04-902', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-west-2:334644584919:training-job/kmeans-2021-09-16-06-33-04-902', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/64e5ba9e-6f6b-4a15-a53f-2b85f7e33e33', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'AWS_REGION': 'us-west-2', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/ff2b1344-d098-4cec-b672-78d0d20989ab', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/ff2b1344-d098-4cec-b672-78d0d20989ab', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.0.203.48', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '2'}
# [09/16/2021 06:36:59 INFO 140274876057408] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-203-48.us-west-2.compute.internal', 'TRAINING_JOB_NAME': 'kmeans-2021-09-16-06-33-04-902', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-west-2:334644584919:training-job/kmeans-2021-09-16-06-33-04-902', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/64e5ba9e-6f6b-4a15-a53f-2b85f7e33e33', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'AWS_REGION': 'us-west-2', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/ff2b1344-d098-4cec-b672-78d0d20989ab', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/ff2b1344-d098-4cec-b672-78d0d20989ab', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.0.203.48', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '2'}
# Process 33 is a shell:scheduler.
# Process 42 is a shell:server.
# Process 1 is a worker.
# [09/16/2021 06:36:59 INFO 140274876057408] Using default worker.
# [09/16/2021 06:36:59 INFO 140274876057408] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [09/16/2021 06:36:59 INFO 140274876057408] Create Store: dist_async
# [09/16/2021 06:37:00 INFO 140129464457024] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'true', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': ''}
# [09/16/2021 06:37:00 INFO 140129464457024] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '784', 'k': '10', 'force_dense': 'True'}
# [09/16/2021 06:37:00 INFO 140129464457024] Final configuration: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '784', 'k': '10'}
# [09/16/2021 06:37:00 WARNING 140129464457024] Loggers have already been setup.
# [09/16/2021 06:37:00 INFO 140129464457024] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-237-137.us-west-2.compute.internal', 'TRAINING_JOB_NAME': 'kmeans-2021-09-16-06-33-04-902', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-west-2:334644584919:training-job/kmeans-2021-09-16-06-33-04-902', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/5980d45e-4110-4e7e-8dbe-91c512dcf424', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'AWS_REGION': 'us-west-2', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/92ce0412-f8be-4ef5-bc93-aa58512c205d', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/92ce0412-f8be-4ef5-bc93-aa58512c205d', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.0.203.48', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '2'}
# Process 1 is a worker.
# [09/16/2021 06:37:00 INFO 140274876057408] nvidia-smi: took 0.029 seconds to run.
# [09/16/2021 06:37:00 INFO 140274876057408] nvidia-smi identified 0 GPUs.
# [09/16/2021 06:37:00 INFO 140274876057408] Number of GPUs being used: 0
# [09/16/2021 06:37:00 INFO 140274876057408] Checkpoint loading and saving are disabled.
# [09/16/2021 06:37:01 INFO 140274876057408] Setting up with params: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '784', 'k': '10'}
# [09/16/2021 06:37:01 INFO 140274876057408] 'extra_center_factor' was set to 'auto', evaluated to 10.
# [09/16/2021 06:37:01 INFO 140274876057408] Number of GPUs being used: 0
# [09/16/2021 06:37:01 INFO 140274876057408] number of center slices 1
# #metrics {"StartTime": 1631774221.0586405, "EndTime": 1631774221.058676, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Total Batches Seen": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Max Records Seen Between Resets": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# [2021-09-16 06:37:01.070] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 88, "num_examples": 1, "num_bytes": 15820000}
# [2021-09-16 06:37:01.526] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 455, "num_examples": 5, "num_bytes": 79100000}
# [09/16/2021 06:37:01 INFO 140274876057408] processed a total of 25000 examples
# [09/16/2021 06:37:01 INFO 140274876057408] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1631774221.0704563, "EndTime": 1631774221.526895, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 30000.0, "count": 1, "min": 30000, "max": 30000}, "Total Batches Seen": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
#
# [09/16/2021 06:37:01 INFO 140274876057408] #throughput_metric: host=algo-1, train throughput=54745.463791254515 records/second
# [09/16/2021 06:37:01 INFO 140274876057408] shrinking 100 centers into 10
# [09/16/2021 06:37:01 INFO 140274876057408] local kmeans attempt #0. Current mean square distance 10.990902
# [09/16/2021 06:37:01 INFO 140274876057408] local kmeans attempt #1. Current mean square distance 10.987697
# [09/16/2021 06:37:01 INFO 140274876057408] local kmeans attempt #2. Current mean square distance 11.089196
# [09/16/2021 06:37:01 INFO 140274876057408] local kmeans attempt #3. Current mean square distance 11.601347
# [09/16/2021 06:37:01 INFO 140274876057408] local kmeans attempt #4. Current mean square distance 10.914842
# [09/16/2021 06:37:00 INFO 140129464457024] Using default worker.
# [09/16/2021 06:37:00 INFO 140129464457024] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [09/16/2021 06:37:00 INFO 140129464457024] Create Store: dist_async
# [09/16/2021 06:37:01 INFO 140129464457024] nvidia-smi: took 0.031 seconds to run.
# [09/16/2021 06:37:01 INFO 140129464457024] nvidia-smi identified 0 GPUs.
# [09/16/2021 06:37:01 INFO 140129464457024] Number of GPUs being used: 0
# [09/16/2021 06:37:01 INFO 140129464457024] Checkpoint loading and saving are disabled.
# [09/16/2021 06:37:01 INFO 140129464457024] Setting up with params: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '784', 'k': '10'}
# [09/16/2021 06:37:01 INFO 140129464457024] 'extra_center_factor' was set to 'auto', evaluated to 10.
# [09/16/2021 06:37:01 INFO 140129464457024] Number of GPUs being used: 0
# [09/16/2021 06:37:01 INFO 140129464457024] number of center slices 1
# #metrics {"StartTime": 1631774221.1051881, "EndTime": 1631774221.1052487, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Total Batches Seen": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Max Records Seen Between Resets": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# [2021-09-16 06:37:01.113] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 83, "num_examples": 1, "num_bytes": 15820000}
# [2021-09-16 06:37:01.466] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 353, "num_examples": 5, "num_bytes": 79100000}
# [09/16/2021 06:37:01 INFO 140129464457024] processed a total of 25000 examples
# [09/16/2021 06:37:01 INFO 140129464457024] #progress_metric: host=algo-2, completed 100.0 % of epochs
# #metrics {"StartTime": 1631774221.1131523, "EndTime": 1631774221.4676657, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 30000.0, "count": 1, "min": 30000, "max": 30000}, "Total Batches Seen": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
#
# [09/16/2021 06:37:01 INFO 140129464457024] #throughput_metric: host=algo-2, train throughput=70491.6985822683 records/second
# [09/16/2021 06:37:01 INFO 140129464457024] shrinking 100 centers into 10
# [09/16/2021 06:37:01 INFO 140129464457024] local kmeans attempt #0. Current mean square distance 12.169878
# [09/16/2021 06:37:01 INFO 140129464457024] local kmeans attempt #1. Current mean square distance 10.926258
# [09/16/2021 06:37:01 INFO 140129464457024] local kmeans attempt #2. Current mean square distance 11.699748
# [09/16/2021 06:37:01 INFO 140129464457024] local kmeans attempt #3. Current mean square distance 11.011677
# [09/16/2021 06:37:01 INFO 140129464457024] local kmeans attempt #4. Current mean square distance 10.871911
# [09/16/2021 06:37:01 INFO 140274876057408] local kmeans attempt #5. Current mean square distance 11.284865
# [09/16/2021 06:37:01 INFO 140274876057408] local kmeans attempt #6. Current mean square distance 11.045362
# [09/16/2021 06:37:01 INFO 140274876057408] local kmeans attempt #7. Current mean square distance 11.411941
# [09/16/2021 06:37:01 INFO 140274876057408] local kmeans attempt #8. Current mean square distance 11.273954
# [09/16/2021 06:37:02 INFO 140274876057408] local kmeans attempt #9. Current mean square distance 11.429266
# [09/16/2021 06:37:02 INFO 140274876057408] finished shrinking process. Mean Square Distance = 11
# [09/16/2021 06:37:02 INFO 140274876057408] #quality_metric: host=algo-1, train msd <loss>=10.914841651916504
# [09/16/2021 06:37:02 INFO 140274876057408] compute all data-center distances: point norm took: 31.3843%, (0.146141 secs)
# [09/16/2021 06:37:02 INFO 140274876057408] compute all data-center distances: inner product took: 23.9175%, (0.111372 secs)
# [09/16/2021 06:37:02 INFO 140274876057408] batch data loading with context took: 13.6732%, (0.063669 secs)
# [09/16/2021 06:37:02 INFO 140274876057408] gradient: cluster center took: 10.6264%, (0.049482 secs)
# [09/16/2021 06:37:02 INFO 140274876057408] predict compute msd took: 7.5954%, (0.035368 secs)
# [09/16/2021 06:37:02 INFO 140274876057408] collect from kv store took: 3.6776%, (0.017125 secs)
# [09/16/2021 06:37:02 INFO 140274876057408] gradient: cluster size  took: 3.5996%, (0.016762 secs)
# [09/16/2021 06:37:02 INFO 140274876057408] splitting centers key-value pair took: 2.6143%, (0.012173 secs)
# [09/16/2021 06:37:02 INFO 140274876057408] gradient: one_hot took: 1.3811%, (0.006431 secs)
# [09/16/2021 06:37:02 INFO 140274876057408] compute all data-center distances: center norm took: 0.8908%, (0.004148 secs)
# [09/16/2021 06:37:02 INFO 140274876057408] update state and report convergance took: 0.5411%, (0.002520 secs)
# [09/16/2021 06:37:02 INFO 140274876057408] update set-up time took: 0.0644%, (0.000300 secs)
# [09/16/2021 06:37:02 INFO 140274876057408] predict minus dist took: 0.0343%, (0.000160 secs)
# [09/16/2021 06:37:02 INFO 140274876057408] TOTAL took: 0.465651273727417
# [09/16/2021 06:37:02 INFO 140274876057408] Number of GPUs being used: 0
# #metrics {"StartTime": 1631774220.98166, "EndTime": 1631774222.0250218, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 53.40766906738281, "count": 1, "min": 53.40766906738281, "max": 53.40766906738281}, "epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 456.21705055236816, "count": 1, "min": 456.21705055236816, "max": 456.21705055236816}, "_shrink.time": {"sum": 494.13394927978516, "count": 1, "min": 494.13394927978516, "max": 494.13394927978516}, "finalize.time": {"sum": 496.95897102355957, "count": 1, "min": 496.95897102355957, "max": 496.95897102355957}, "model.serialize.time": {"sum": 0.23674964904785156, "count": 1, "min": 0.23674964904785156, "max": 0.23674964904785156}}}
#
# [09/16/2021 06:37:02 INFO 140274876057408] Test data is not provided.
# #metrics {"StartTime": 1631774222.0251381, "EndTime": 1631774222.0254178, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 25.81167221069336, "count": 1, "min": 25.81167221069336, "max": 25.81167221069336}, "totaltime": {"sum": 2696.4352130889893, "count": 1, "min": 2696.4352130889893, "max": 2696.4352130889893}}}
#
# [09/16/2021 06:37:01 INFO 140129464457024] local kmeans attempt #5. Current mean square distance 11.217882
# [09/16/2021 06:37:01 INFO 140129464457024] local kmeans attempt #6. Current mean square distance 11.699720
# [09/16/2021 06:37:02 INFO 140129464457024] local kmeans attempt #7. Current mean square distance 11.283781
# [09/16/2021 06:37:02 INFO 140129464457024] local kmeans attempt #8. Current mean square distance 11.453973
# [09/16/2021 06:37:02 INFO 140129464457024] local kmeans attempt #9. Current mean square distance 11.163606
# [09/16/2021 06:37:02 INFO 140129464457024] finished shrinking process. Mean Square Distance = 11
# [09/16/2021 06:37:02 INFO 140129464457024] #quality_metric: host=algo-2, train msd <loss>=10.87191104888916
# [09/16/2021 06:37:02 INFO 140129464457024] compute all data-center distances: point norm took: 30.6756%, (0.109866 secs)
# [09/16/2021 06:37:02 INFO 140129464457024] compute all data-center distances: inner product took: 18.9729%, (0.067952 secs)
# [09/16/2021 06:37:02 INFO 140129464457024] batch data loading with context took: 13.6962%, (0.049053 secs)
# [09/16/2021 06:37:02 INFO 140129464457024] collect from kv store took: 9.6854%, (0.034689 secs)
# [09/16/2021 06:37:02 INFO 140129464457024] gradient: cluster center took: 9.0978%, (0.032584 secs)
# [09/16/2021 06:37:02 INFO 140129464457024] predict compute msd took: 7.1786%, (0.025711 secs)
# [09/16/2021 06:37:02 INFO 140129464457024] gradient: cluster size  took: 3.9939%, (0.014304 secs)
# [09/16/2021 06:37:02 INFO 140129464457024] gradient: one_hot took: 2.7567%, (0.009873 secs)
# [09/16/2021 06:37:02 INFO 140129464457024] splitting centers key-value pair took: 2.3706%, (0.008491 secs)
# [09/16/2021 06:37:02 INFO 140129464457024] compute all data-center distances: center norm took: 0.9113%, (0.003264 secs)
# [09/16/2021 06:37:02 INFO 140129464457024] update state and report convergance took: 0.5391%, (0.001931 secs)
# [09/16/2021 06:37:02 INFO 140129464457024] update set-up time took: 0.0806%, (0.000289 secs)
# [09/16/2021 06:37:02 INFO 140129464457024] predict minus dist took: 0.0412%, (0.000148 secs)
# [09/16/2021 06:37:02 INFO 140129464457024] TOTAL took: 0.3581540584564209
# [09/16/2021 06:37:02 INFO 140129464457024] Number of GPUs being used: 0
# [09/16/2021 06:37:02 INFO 140129464457024] No model is serialized on a non-master node
# #metrics {"StartTime": 1631774221.0295181, "EndTime": 1631774222.1891725, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 53.034067153930664, "count": 1, "min": 53.034067153930664, "max": 53.034067153930664}, "epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 354.30383682250977, "count": 1, "min": 354.30383682250977, "max": 354.30383682250977}, "_shrink.time": {"sum": 610.6932163238525, "count": 1, "min": 610.6932163238525, "max": 610.6932163238525}, "finalize.time": {"sum": 615.074634552002, "count": 1, "min": 615.074634552002, "max": 615.074634552002}, "model.serialize.time": {"sum": 0.11301040649414062, "count": 1, "min": 0.11301040649414062, "max": 0.11301040649414062}}}
#
# [09/16/2021 06:37:02 INFO 140129464457024] Test data is not provided.
# #metrics {"StartTime": 1631774222.189311, "EndTime": 1631774222.1926546, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 20.829439163208008, "count": 1, "min": 20.829439163208008, "max": 20.829439163208008}, "totaltime": {"sum": 1356.384515762329, "count": 1, "min": 1356.384515762329, "max": 1356.384515762329}}}
#
#
# 2021-09-16 06:37:29 Completed - Training job completed
# Training seconds: 106
# Billable seconds: 106
# CPU times: user 39.4 s, sys: 1.82 s, total: 41.2 s
# Wall time: 5min 43s

# %% [markdown]
# ## Set up hosting for the model
# Now, we can deploy the model we just trained behind a real-time hosted endpoint.  This next step can take, on average, 7 to 11 minutes to complete.

# %%
# %%time

kmeans_predictor = kmeans.deploy(initial_instance_count=1, instance_type="ml.m4.xlarge")
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -------------!CPU times: user 347 ms, sys: 0 ns, total: 347 ms
# Wall time: 6min 31s

# %% [markdown]
# ## Validate the model for use
# Finally, we'll validate the model for use. Let's generate a classification for a single observation from the trained model using the endpoint we just created.

# %%
result = kmeans_predictor.predict(train_set[0][30:31])
print(result)
# Out:
# [label {
#   key: "closest_cluster"
#   value {
#     float32_tensor {
#       values: 0.0
#     }
#   }
# }
# label {
#   key: "distance_to_cluster"
#   value {
#     float32_tensor {
#       values: 7.446356773376465
#     }
#   }
# }
# ]

# %% [markdown]
# OK, a single prediction works.
#
# Let's do a whole batch and see how well the clustering works.

# %%
# %%time

result = kmeans_predictor.predict(valid_set[0][0:100])
clusters = [r.label["closest_cluster"].float32_tensor.values[0] for r in result]
# Out:
# CPU times: user 23.7 ms, sys: 0 ns, total: 23.7 ms
# Wall time: 123 ms

# %%
for cluster in range(10):
    print(f"\n\n\nCluster {int(cluster)}:")
    digits = [img for l, img in zip(clusters, valid_set[0]) if int(l) == cluster]
    height = ((len(digits) - 1) // 5) + 1
    width = 5
    plt.rcParams["figure.figsize"] = (width, height)
    _, subplots = plt.subplots(height, width)
    subplots = numpy.ndarray.flatten(subplots)
    for subplot, image in zip(subplots, digits):
        show_digit(image, subplot=subplot)
    for subplot in subplots[len(digits) :]:
        subplot.axis("off")

    plt.show()
# Out:
# Cluster 0:
# Cluster 1:
# Cluster 2:
# Cluster 3:
# Cluster 4:
# Cluster 5:
# Cluster 6:
# Cluster 7:
# Cluster 8:
# Cluster 9:

# %% [markdown]
# ### The bottom line
#
# K-Means clustering is not the best algorithm for image analysis problems, but we do see pretty reasonable clusters being built.

# %% [markdown]
# ### (Optional) Delete the Endpoint
# If you're ready to be done with this notebook, make sure run the cell below.  This will remove the hosted endpoint you created and avoid any charges from a stray instance being left on.

# %%
print(kmeans_predictor.endpoint)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# kmeans-2021-09-16-06-38-05-186

# %%
kmeans_predictor.delete_endpoint()
